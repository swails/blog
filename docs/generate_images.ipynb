# %%
import matplotlib.pyplot as plt
import seaborn
import numpy as np

seaborn.set_theme()

# %%
process_x = np.arange(101)
process_y = - process_x * process_x + 100 * process_x

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = fig.add_subplot(111)
ax.set_ylabel("Productivity")
ax.set_xlabel("Process")
ax.get_xaxis().grid(visible=False)
ax.get_yaxis().grid(visible=False)
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.plot(process_x, process_y)

fig.savefig("software-development-architecture/productivity-vs-process.svg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 11
#       8 ax.set_yticklabels([])
#       9 ax.plot(process_x, process_y)
# ---> 11 fig.savefig("software-development-architecture/productivity-vs-process.svg")
#
# File /Applications/Anaconda/anaconda3/envs/blog-env/lib/python3.11/site-packages/matplotlib/figure.py:3274, in Figure.savefig(self, fname, transparent, **kwargs)
#    3270     for ax in self.axes:
#    3271         stack.enter_context(
#    3272             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3274 self.canvas.print_figure(fname, **kwargs)
#
# File /Applications/Anaconda/anaconda3/envs/blog-env/lib/python3.11/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
# ...

# %%
# !ls
# Out:
# generate_images.ipynb main.md
